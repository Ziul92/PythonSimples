# %%
import json

# %%
caminho_pasta = fr"C:\Users\luizh\OneDrive\Aulas Impacta\Cursos Livres\Aulas Udemy\pandas\dados"

# %%
dados_receita = {
    "receitas": [
        {
            "titulo": "Bolo de Chocolate",
            "tempo_preparo": "45 minutos",
            "porcoes": 8,
            "ingredientes": [
                {"ingrediente": "Faria de Trigo", "quantidade" : "2 xícaras"},
                {"ingrediente": "Açucar", "quantidade": "1 xícara"},
                {"ingrediente": "Ovos", "quantidade": "3 xícaras"},
                {"ingrediente": "Leite", "quantidade": "1 xícara"},
                {"ingrediente": "Manteira", "quantidade": "1 xícara"}
            ]
        },
        {
            "titulo": "Salada Caesar",
            "tempo_preparo": "20 minutos",
            "porcoes": 4,
            "ingredientes": [
                {"ingrediente": "Alface Romana", "quantidade" : "1 cabeça"},
                {"ingrediente": "Croutons", "quantidade" : "1 xícara"},
                {"ingrediente": "Queijo Parmesão", "quantidade" : "1 xícara"},
                {"ingrediente": "Molho Caesar", "quantidade" : "1/4 xícara"}
            ]
        },
                {
            "titulo": "Pasta ao Pesto",
            "tempo_preparo": "20 minutos",
            "porcoes": 4,
            "ingredientes": [
                {"ingrediente": "Alface Romana", "quantidade" : "1 cabeça"},
                {"ingrediente": "Croutons", "quantidade" : "1 xícara"},
                {"ingrediente": "Queijo Parmesão", "quantidade" : "1 xícara"},
                {"ingrediente": "Molho Caesar", "quantidade" : "1/4 xícara"}
            ]
        }
    ]
}

# %%
with open(fr"{caminho_pasta}\receitas.json", "w", encoding="utf-8") as file:
    json.dump(dados_receita, file, ensure_ascii=False, indent=4)
