# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.3.5'

# %%
arr = np.array([1, 2, 3, 4, 5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
soma = arr + 10
print("Array após somar 10:", soma)
# Out:
# Array após somar 10: [11 12 13 14 15]

# %%
soma = arr * 2
print("Array após multiplicar por 2:", soma)
# Out:
# Array após multiplicar por 2: [ 2  4  6  8 10]

# %%
media = np.mean(arr)
print("Média do array:", media)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 media = np.mean(arr)
#       2 print("Média do array:", media)
#
# NameError: name 'np' is not defined
